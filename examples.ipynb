# %%
from streamings import StreamingAnalyzer
import requests

sa = StreamingAnalyzer()

# %%
sa.get_all_streaming_data('netflix')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
sa.get_streaming_data_by_actor('amazon', 'Karl Urban')
# Out:
#      show_id     type                          title  director  \
# 730     s731  TV Show                       The Boys       NaN
# 1260   s1261  TV Show  Prime Rewind: Inside The Boys       NaN
#
#                                                    cast        country  \
# 730   Karl Urban, Jack Quaid, Antony Starr, Erin Mor...  United States
# 1260                Aisha Tyler, Karl Urban, Laz Alonso  United States
#
#       date_added  release_year rating   duration              listed_in  \
# 730          NaN          2020    18+  2 Seasons                 Action
# 1260         NaN          2020    18+   1 Season  Talk Show and Variety
#
#                                             description
# 730   All Episodes Available. In a more intense Seas...
# 1260  "The Boys" Official After Show, hosted by Aish...

# %%
sa.get_streaming_data_by_genre('disney_plus', 'drama')
# Out:
#      show_id   type                               title             director  \
# 2         s3  Movie              The Fault in Our Stars           Josh Boone
# 29       s30  Movie                             Cruella      Craig Gillespie
# 30       s31  Movie                    Dan in Real Life         Peter Hedges
# 32       s33  Movie  Marvel One-Shot: All Hail the King          Drew Pearce
# 51       s52  Movie                      Mrs. Doubtfire       Chris Columbus
# ...      ...    ...                                 ...                  ...
# 1317   s1318  Movie                    Tuck Everlasting          Jay Russell
# 1330   s1331  Movie                          White Fang       Randal Kleiser
# 1348   s1349  Movie                           You Wish!            Paul Hoen
# 1358   s1359  Movie           Justin Morgan had a Horse  Hollingsworth Morse
# 1364   s1365  Movie                     Those Calloways         Norman Tokar
#
# ...

# %%
sa.get_streaming_data_by_country('netflix', 'Brazil')
# Out:
#      show_id     type                              title  \
# 270     s271    Movie                            Beckett
# 302     s303    Movie        City of God: 10 Years Later
# 650     s651    Movie               O Vendedor de Sonhos
# 783     s784    Movie                           Carnaval
# 894     s895    Movie             Dance of the Forty One
# ...      ...      ...                                ...
# 8207   s8208  TV Show  The Beginning of Life: The Series
# 8300   s8301    Movie     The First Temptation of Christ
# 8386   s8387    Movie                  The Last Hangover
# 8617   s8618    Movie                              Trash
# 8702   s8703    Movie                        Waterschool
#
#                           director  \
# 270     Ferdinando Cito Filomarino
# 302   Cavi Borges, Luciano Vidigal
# 650                Jayme Monjardim
# 783                   Leandro Neri
# 894                   David Pablos
# ...                            ...
# ...

# %%
sa.get_streaming_data_by_year('amazon', '1999')
# Out:
#      show_id     type                             title           director  \
# 391     s392    Movie                   The Winslow Boy        David Mamet
# 417     s418  TV Show             The Toothbrush Family               None
# 471     s472    Movie                    The Real Macaw  Mario Andreacchio
# 523     s524    Movie       The Mystery of Chaco Canyon        Anna Sofaer
# 552     s553    Movie            The Lucy Show - Vol. 1     Maury Thompson
# ...      ...      ...                               ...                ...
# 9385   s9386    Movie                          Flawless    Joel Schumacher
# 9521   s9522    Movie  The World is Not Enough (4K UHD)      Michael Apted
# 9522   s9523    Movie           The World Is Not Enough      Michael Apted
# 9606   s9607    Movie                         Blue Moon    Ron Lagomarsino
# 9659   s9660    Movie        10 Things I Hate About You         Gil Junger
#
# ...

# %%
sa.get_streaming_data_by_director('amazon', 'Steven Spielberg')
# Out:
#      show_id   type                title          director  \
# 6305   s6306  Movie      Minority Report  Steven Spielberg
# 7041   s7042  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                    cast  \
# 6305  Tom Cruise, Colin Farrell, Samantha Morton, Ma...
# 7041  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
#
#                     country  date_added  release_year rating duration  \
# 6305          United States         NaN          2002  PG-13  145 min
# 7041  United States, Canada         NaN          2002  PG-13  141 min
#
#                    listed_in  \
# 6305  Drama, Science Fiction
# 7041                Suspense
#
#                                             description
# 6305  Set in Washington D.C. in 2054, where police u...
# 7041  From three-time Oscar winning director Steven ...

# %%
sa.get_streaming_data_by_director('netflix', 'Luciano Vidigal')
# Out:
#     show_id   type                        title                      director  \
# 302    s303  Movie  City of God: 10 Years Later  Cavi Borges, Luciano Vidigal
#
#      cast country      date_added  release_year rating duration  \
# 302   NaN  Brazil  August 5, 2021          2013  TV-MA   69 min
#
#                                listed_in  \
# 302  Documentaries, International Movies
#
#                                            description
# 302  A decade after the seminal Brazilian film "Cit...

# %%
sa.get_streaming_data_by_duration('amazon', '90')
# Out:
#      show_id   type                     title                 director  \
# 126     s127  Movie  When a Woman Loves A Man  Jamall Rashaud McMillan
# 175     s176  Movie      Voice From the Stone           Eric D. Howell
# 207     s208  Movie                   Useless           Josiah Burdick
# 220     s221  Movie               Underplayed               Stacey Lee
# 351     s352  Movie     Three Guys Named Mike          Charles Walters
# ...      ...    ...                       ...                      ...
# 9580   s9581  Movie            Staying Afloat          Eric Laneuville
# 9594   s9595  Movie      John Tucker Must Die             Betty Thomas
# 9608   s9609  Movie           A Perfect Enemy              Kike Maíllo
# 9616   s9617  Movie             Tooth Fairy 2                Alex Zamm
# 9665   s9666  Movie                   Outpost             Steve Barker
#
#                                                    cast               country  \
# ...

# %%
sa.count_streaming_by_actor('Brad Pitt')
# Out:
# '{"amazon": 2, "netflix": 8, "disney_plus": 0, "hulu": null}'

# %%
sa.count_streaming_by_genre('action')
# Out:
# '{"amazon": 1657, "netflix": 1027, "disney_plus": 438, "hulu": 555}'

# %%
sa.count_streaming_by_director('Steven Spielberg')
# Out:
# '{"amazon": 2, "netflix": 11, "disney_plus": 0, "hulu": 0}'

# %%
sa.count_streaming_by_year('2000')
# Out:
# '{"amazon": 81, "netflix": 37, "disney_plus": 26, "hulu": 23}'

# %%
sa.count_streaming_by_country('France')
# Out:
# '{"amazon": 20, "netflix": 393, "disney_plus": 21, "hulu": 40}'
